# %%
import joblib

# %%
model=joblib.load('review.pkl')

# %%
model.predict(['Poor service and bland taste. Nothing special about the meal.'])
# Out:
# array([0], dtype=int64)

# %%
model.predict_proba(["Poor service and bland taste. Nothing special about the meal."])
# Out:
# array([[0.76337847, 0.23662153]])
